# %% [markdown]
# <a href="https://colab.research.google.com/github/rohapatinadwiputri-oss/Pemerograman-Dasar/blob/main/Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#latihan1
tegangan = 18
arus = 6
nama_alat = "monocrystalline"

print(tegangan, arus, nama_alat)
print()

#latihan2
tegangan = 12
arus = 2.5
aktif = True
komponen = "Resistor"

print(tegangan, type(tegangan))
print(arus, type(arus))
print(aktif, type(arus))
print(komponen, type(komponen))
print()

#latihan3
nama_unit = "PLTS Nunukan"                                       #str
jumlah_panel = 240                                               #int
tegangan_keluar = 48.5                                           #float
sedang_beroprasi = True                                          #bool

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluar, type(tegangan_keluar))
print(sedang_beroprasi, type(sedang_beroprasi))
print()

#latihan4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Pertama:", tegangan_harian[0])
print("Terakhir:", tegangan_harian[5])
tegangan_harian.append(222.0)
print("jumlah_data:", len(tegangan_harian))
print()

#latihan5
motor = {"nama": "Motor Listrik BLDC", "daya_kW": 3, "tegangan_v": 72, "rpm": 3000}
print(motor["tegangan_v"])
motor["rpm"] = 2500
print(motor)
print()

#latihan6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

print("unit kedua:", pembangkit[1]["nama"])
pembangkit[0]["status"] = "pemeliharaan"
pembangkit.append({"nama": "unit-4", "kapasitas_MW": 100, "status": "pemeliharaan"})
print(pembangkit)
# Out:
# 18 6 monocrystalline
#
# 12 <class 'int'>
# 2.5 <class 'float'>
# True <class 'float'>
# Resistor <class 'str'>
#
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
#
# Pertama: 217.5
# Terakhir: 216.9
# jumlah_data: 7
#
# 3
# {'nama': 'Motor Listrik BLDC', 'daya_kW': 3, 'tegangan_v': 72, 'rpm': 2500}
#
# unit kedua: Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'unit-4', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}]
